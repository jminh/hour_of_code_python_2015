# %% [markdown]
# # Using Tumblr API
#
# ## GitHub:
# - https://github.com/tumblr/pytumblr

# %%
import pytumblr
from tumblr_auth import consumer_key, consumer_secret, oauth_token, oauth_secret

# %%
client = pytumblr.TumblrRestClient(
    consumer_key,
    consumer_secret,
    oauth_token,
    oauth_secret,
)

# %%
type(client)

# %%
tumblr_user = "codingjester"

# %%
client.blog_info(tumblr_user)

# %% [raw]
# ### client.blog_info(tumblr_user)
#
# {u'blog': {u'ask': True,  # ------------------------------------------------------------------------- BLOG INFO
#   u'ask_anon': True,
#   u'ask_page_title': u'Ask me anything',
#   u'can_send_fan_mail': False,
#   u'can_submit': True,
#   u'can_subscribe': False,
#   u'description': u'Hey, My name is John. Formerly @ Tumblr. I love software, tech and anything geeky. Follow me here or @codingjester.',
#   u'followed': False,
#   u'is_blocked_from_primary': False,
#   u'is_nsfw': False,
#   u'likes': 3371,
#   u'name': u'codingjester',
#   u'posts': 2124,
#   u'share_likes': True,
#   u'submission_page_title': u'Submit',
#   u'subscribed': False,
#   u'title': u'/geek',
#   u'updated': 1447867728,
#   u'url': u'http://tumblr.johnbunting.me/'},  # ----------------------------------------------------- BLOG INFO
#  u'posts': [{u'blog_name': u'codingjester',  # ------------------------------------------------------ POST INFO LIST
#    u'can_reply': False,
#    u'caption': u'<p><a class="tumblr_blog" href="http://reneeejp.tumblr.com/post/133471081438" target="_blank">reneeejp</a>:</p>\n<blockquote>\n<p><a href="http://@codingjester" target="_blank">John</a> cooked last night\u2026</p>\n</blockquote>\n\n<p>I\u2019m a good cook. Fuck you guys. This is exactly what I intended while boiling water.</p><p><br/></p><p><br/></p><p>dicks.<br/></p>',
#    u'date': u'2015-11-18 17:28:48 GMT',
#    u'followed': False,
#    u'format': u'html',
#    u'highlighted': [],
#    u'html5_capable': True,
#    u'id': 133473575350,
#    u'liked': False,
#    u'note_count': 19,
#    u'permalink_url': u'https://vine.co/v/iumnBVPuzDz',
#    u'placement_id': u'{"i":"Eq54wbc4qxIFXwDcgRw3","v":4,"t":1448784219,"c":{"p":"133473575350","b":"codingjester"},"d":{"v":{"e":"iumnBVPuzDz"}},"h":"d66665ea1d"}',
#    u'player': [{u'embed_code': u'<iframe class="vine-embed" src="https://vine.co/v/iumnBVPuzDz/embed/simple" width="250" height="250" frameborder="0"></iframe><script async src="//platform.vine.co/static/scripts/embed.js"></script>',
#      u'width': 250},
#     {u'embed_code': u'<iframe class="vine-embed" src="https://vine.co/v/iumnBVPuzDz/embed/simple" width="400" height="400" frameborder="0"></iframe><script async src="//platform.vine.co/static/scripts/embed.js"></script>',
#      u'width': 400},
#     {u'embed_code': u'<iframe class="vine-embed" src="https://vine.co/v/iumnBVPuzDz/embed/simple" width="500" height="500" frameborder="0"></iframe><script async src="//platform.vine.co/static/scripts/embed.js"></script>',
#      u'width': 500}],
#    u'post_url': u'http://tumblr.johnbunting.me/post/133473575350/reneeejp-john-cooked-last-night-im-a-good',
#    u'reblog': {u'comment': u'<p>I\u2019m a good cook. Fuck you guys. This is exactly what I intended while boiling water.</p><p><br></p><p><br></p><p>dicks.<br></p>',
#     u'tree_html': u'<p><a class="tumblr_blog" href="http://reneeejp.tumblr.com/post/133471081438" target="_blank">reneeejp</a>:</p><blockquote>\n<p><a href="http://@codingjester" target="_blank">John</a> cooked last night\u2026</p>\n</blockquote>'},
#    u'reblog_key': u'z4vFyVzK',
#    u'recommended_color': None,
#    u'recommended_source': None,
#    u'short_url': u'http://tmblr.co/Z9Yjvx1yJfI6s',
#    u'slug': u'reneeejp-john-cooked-last-night-im-a-good',
#    u'state': u'published',
#    u'summary': u'reneeejp:\n\n John cooked last night\u2026\n\n\n I\u2019m a good cook. Fuck you guys. This is exactly what I intended while boiling water.  ...',
#    u'tags': [],
#    u'thumbnail_height': 480,
#    u'thumbnail_url': u'https://v.cdn.vine.co/r/videos/772C7B89061278550743980314624_SW_WEBM_1447804463557c396136c7e.webm.jpg?versionId=isOgHXbtfQ0GCMKwFHtRiEyiA65X1zk2',
#    u'thumbnail_width': 480,
#    u'timestamp': 1447867728,
#    u'trail': [{u'blog': {u'active': True,
#       u'name': u'reneeejp',
#       u'theme': {u'avatar_shape': u'square',
#        u'background_color': u'#8d5b34',
#        u'body_font': u'Helvetica Neue',
#        u'header_bounds': u'369,960,910,0',
#        u'header_focus_height': 541,
#        u'header_focus_width': 960,
#        u'header_full_height': 1280,
#        u'header_full_width': 960,
#        u'header_image': u'https://secure.static.tumblr.com/bf07d9b26a0dc405d6c7e6b579281d14/mf7kqmz/Pbinf8qsb/tumblr_static_34chotgdb4sg0oco88s0gos0k.jpg',
#        u'header_image_focused': u'https://secure.static.tumblr.com/bf07d9b26a0dc405d6c7e6b579281d14/mf7kqmz/JD1nf8qsd/tumblr_static_tumblr_static_34chotgdb4sg0oco88s0gos0k_focused_v3.jpg',
#        u'header_image_scaled': u'https://secure.static.tumblr.com/bf07d9b26a0dc405d6c7e6b579281d14/mf7kqmz/Pbinf8qsb/tumblr_static_34chotgdb4sg0oco88s0gos0k_2048_v2.jpg',
#        u'header_stretch': True,
#        u'link_color': u'#301f14',
#        u'show_avatar': True,
#        u'show_description': True,
#        u'show_header_image': True,
#        u'show_title': True,
#        u'title_color': u'#301f14',
#        u'title_font': u'Helvetica Neue',
#        u'title_font_weight': u'bold'}},
#      u'content': u'<p><a href="http://@codingjester" target="_blank">John</a> cooked last night\u2026</p>',
#      u'content_raw': u'<p><a href="http://@codingjester" target="_blank">John</a> cooked last night\u2026</p>',
#      u'is_root_item': True,
#      u'post': {u'id': u'133471081438'}},
#     {u'blog': {u'active': True,
#       u'name': u'codingjester',
#       u'theme': {u'avatar_shape': u'circle',
#        u'background_color': u'#fafafa',
#        u'body_font': u'Helvetica Neue',
#        u'header_bounds': u'56,1080,663,0',
#        u'header_focus_height': 607,
#        u'header_focus_width': 1080,
#        u'header_full_height': 720,
#        u'header_full_width': 1080,
#        u'header_image': u'https://secure.static.tumblr.com/eb8cd4f05abcaa206aeb8e4cd3c4b64a/lejyfcf/E4mng0imc/tumblr_static_2dkdz3tvwgissggco080wk0k8.jpg',
#        u'header_image_focused': u'https://secure.static.tumblr.com/eb8cd4f05abcaa206aeb8e4cd3c4b64a/lejyfcf/9Ghng0imf/tumblr_static_tumblr_static_2dkdz3tvwgissggco080wk0k8_focused_v3.jpg',
#        u'header_image_scaled': u'https://secure.static.tumblr.com/eb8cd4f05abcaa206aeb8e4cd3c4b64a/lejyfcf/E4mng0imc/tumblr_static_2dkdz3tvwgissggco080wk0k8_2048_v2.jpg',
#        u'header_stretch': True,
#        u'link_color': u'#529ecc',
#        u'show_avatar': True,
#        u'show_description': True,
#        u'show_header_image': True,
#        u'show_title': True,
#        u'title_color': u'#444444',
#        u'title_font': u'Helvetica Neue',
#        u'title_font_weight': u'bold'}},
#      u'content': u'<p>I\u2019m a good cook. Fuck you guys. This is exactly what I intended while boiling water.</p><p><br /></p><p><br /></p><p>dicks.<br /></p>',
#      u'content_raw': u'<p>I\u2019m a good cook. Fuck you guys. This is exactly what I intended while boiling water.</p><p><br></p><p><br></p><p>dicks.<br></p>',
#      u'is_current_item': True,
#      u'post': {u'id': u'133473575350'}}],
#    u'type': u'video',
#    u'video_type': u'vine'},
#   {u'blog_name': u'codingjester',
#    u'can_reply': False,
#    u'caption': u'',
#    u'date': u'2015-10-14 14:00:21 GMT',
#    u'followed': False,
#    u'format': u'html',
#    u'highlighted': [],
#    u'id': 131154894232,
#    u'image_permalink': u'http://tumblr.johnbunting.me/image/131154894232',
#    u'liked': False,
#    u'note_count': 5628,
#    u'photos': [{u'alt_sizes': [{u'height': 598,
#        u'url': u'https://49.media.tumblr.com/5bbfd7bb60504d3cd8088d8fcd342b61/tumblr_ntm93aYvF51rmehl4o1_1280.gif',
#        u'width': 800},
#       {u'height': 374,
#        u'url': u'https://49.media.tumblr.com/5bbfd7bb60504d3cd8088d8fcd342b61/tumblr_ntm93aYvF51rmehl4o1_500.gif',
#        u'width': 500},
#       {u'height': 299,
#        u'url': u'https://49.media.tumblr.com/5bbfd7bb60504d3cd8088d8fcd342b61/tumblr_ntm93aYvF51rmehl4o1_400.gif',
#        u'width': 400},
#       {u'height': 187,
#        u'url': u'https://49.media.tumblr.com/5bbfd7bb60504d3cd8088d8fcd342b61/tumblr_ntm93aYvF51rmehl4o1_250.gif',
#        u'width': 250},
#       {u'height': 75,
#        u'url': u'https://49.media.tumblr.com/5bbfd7bb60504d3cd8088d8fcd342b61/tumblr_ntm93aYvF51rmehl4o1_100.gif',
#        u'width': 100},
#       {u'height': 75,
#        u'url': u'https://45.media.tumblr.com/5bbfd7bb60504d3cd8088d8fcd342b61/tumblr_ntm93aYvF51rmehl4o1_75sq.gif',
#        u'width': 75}],
#      u'caption': u'',
#      u'original_size': {u'height': 598,
#       u'url': u'https://49.media.tumblr.com/5bbfd7bb60504d3cd8088d8fcd342b61/tumblr_ntm93aYvF51rmehl4o1_1280.gif',
#       u'width': 800}}],
#    u'post_url': u'http://tumblr.johnbunting.me/post/131154894232',
#    u'reblog': {u'comment': u'', u'tree_html': u''},
#    u'reblog_key': u'9EQv4Pyg',
#    u'recommended_color': None,
#    u'recommended_source': None,
#    u'short_url': u'http://tmblr.co/Z9Yjvx1w9SDsO',
#    u'slug': u'',
#    u'source_title': u'chintislundgren',
#    u'source_url': u'http://chintislundgren.tumblr.com/post/127524402608/more',
#    u'state': u'published',
#    u'summary': u'',
#    u'tags': [],
#    u'timestamp': 1444831221,
#    u'trail': [],
#    u'type': u'photo'},  # ---------------------------------------------------------------------- ONE OF END POST
#    # ANOTHER POST {...}
#    ]  # ---------------------------------------------------------------------------------------- POST INFO LIST
# }

# %%
posts = client.posts(tumblr_user)
for post in posts.get('posts'):
    if not post.get('photos'):
        continue
    data = post.get('photos')[0]
    print post.get('date')
    print data['original_size']['url']

# %% [markdown]
# 2015-10-14 14:00:21 GMT
# https://49.media.tumblr.com/5bbfd7bb60504d3cd8088d8fcd342b61/tumblr_ntm93aYvF51rmehl4o1_1280.gif
# <img src="images/tumblr/tumblr_ntm93aYvF51rmehl4o1_1280.gif"/>
#
#
#
# 2015-10-13 23:47:18 GMT
# https://49.media.tumblr.com/340f2ae5c9fffc92879e6d1ca08b71d2/tumblr_nvge7uKDxU1upvs5eo1_500.gif
# <img src="images/tumblr/tumblr_nvge7uKDxU1upvs5eo1_500.gif"/>
#
#
# 2015-10-08 01:55:32 GMT
# https://41.media.tumblr.com/34499cfc1ce7f8b435bb01100ead14fc/tumblr_nvumceb40K1roll6uo1_1280.jpg
# <img src="images/tumblr/tumblr_nvumceb40K1roll6uo1_1280.jpg"/>
#
# 2015-10-07 01:56:35 GMT
# https://41.media.tumblr.com/73fbd3fb83833b563c1705cbf2653b05/tumblr_nvttq7Y4AO1s9x8i6o1_1280.jpg
# <img src="images/tumblr/tumblr_nvttq7Y4AO1s9x8i6o1_1280.jpg"/>
#
# 2015-10-06 23:14:11 GMT
# https://49.media.tumblr.com/662d48418a2b9286d9947131f94e2951/tumblr_mwui2jsYrS1qcr7fqo1_500.gif
# <img src="images/tumblr/tumblr_mwui2jsYrS1qcr7fqo1_500.gif"/>
#
# 2015-09-26 16:47:40 GMT
# https://45.media.tumblr.com/7336fff8fe2098c224f777216d3e7426/tumblr_nv8cbuz3Dt1qejjfeo1_500.gif
# <img src="images/tumblr/tumblr_nv8cbuz3Dt1qejjfeo1_500.gif"/>
#
# 2015-09-14 04:40:11 GMT
# https://45.media.tumblr.com/6cbbf7e664d8cdf157dfb1676b58b6ce/tumblr_nun3b0wsyh1qz4u07o1_500.gif
# <img src="images/tumblr/tumblr_nun3b0wsyh1qz4u07o1_500.gif"/>
#
# 2015-08-28 23:46:16 GMT
# https://49.media.tumblr.com/131f9595f1a1cdbaac447c917f686122/tumblr_ntb6bozt7s1qd7ro1o1_540.gif
# <img src="images/tumblr/tumblr_ntb6bozt7s1qd7ro1o1_540.gif"/>
